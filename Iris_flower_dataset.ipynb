# %% [markdown]
# # IRIS FLOWER DATASET

# %% [markdown]
# # Importing all the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %%
iris = datasets.load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Species']=iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Species
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Species              0
# dtype: int64

# %%
df['Species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, kind='scatter')
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.gca()
sns.violinplot(x = 'Species', y = 'petal width (cm)', data=df, ax=ax)
sns.set(font_scale=1.1)
ax.set(title='Species Vs Petal Width')
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.gca()
sns.violinplot(x = 'Species', y = 'petal length (cm)', data=df, ax=ax)
sns.set(font_scale=1.1)
ax.set(title='Species Vs Petal Length')
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.gca()
sns.violinplot(x = 'Species', y = 'sepal width (cm)', data=df, ax=ax)
sns.set(font_scale=1.1)
ax.set(title='Species Vs Sepal Width')
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.gca()
sns.violinplot(x = 'Species', y = 'sepal length (cm)', data=df, ax=ax)
sns.set(font_scale=1.1)
ax.set(title='Species Vs Sepal Length')
plt.show()

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# # Model Construction and Utilization

# %%
x = df.drop('Species', axis=1)
y = df.Species

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=100)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=100)
dt_model = dt.fit(x_train, y_train)

# %%
y_pred = dt_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred, y_test)
# Out:
# array([[20,  0,  0],
#        [ 0, 11,  1],
#        [ 0,  1, 17]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
model_accuracy = accuracy_score(y_pred, y_test)
print('The model\'s accuracy is: ', round(model_accuracy*100, 2))
# Out:
# The model's accuracy is:  96.0
